# %%
'''
This is a starting template to get you into data visualizations and interpretation. Customize
this file and comment out part which you do not need.
We will be using the functionality of the matplotlib library and other libraries, so we import them.'''

import matplotlib.pyplot as plt
import numpy as np
from numpy import *

# %%
data = loadtxt('apartment_prices.dat')

plt.ylabel('price in euros')
plt.title('Apartment prices')
plt.legend()

plt.boxplot(data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xf5de2e8>],
#  'caps': [<matplotlib.lines.Line2D at 0xf5dea20>,
#   <matplotlib.lines.Line2D at 0xf5ded68>],
#  'fliers': [<matplotlib.lines.Line2D at 0xf5ec438>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xf5ec0f0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xf5de390>,
#   <matplotlib.lines.Line2D at 0xf5de6d8>]}

# %%
data = loadtxt('grades_lecture1.dat')
 
plt.xlabel('grade')
plt.ylabel('number of students')
plt.title('Grades lecture 1')
plt.legend()

plt.hist(data,(1,2,3,4,5,6),width=0.9,align='left')
# Out:
# (array([49., 31.,  9.,  8.,  3.]),
#  array([1, 2, 3, 4, 5, 6]),
#  <a list of 5 Patch objects>)

# %%
data = loadtxt('grades_lecture2.dat')
 
plt.xlabel('grade')
plt.ylabel('number of students')
plt.title('Grades lecture 2')
plt.legend()

plt.hist(data,(1,2,3,4,5,6),width=0.9,align='left')
# Out:
# (array([32.,  6.,  4., 13., 45.]),
#  array([1, 2, 3, 4, 5, 6]),
#  <a list of 5 Patch objects>)

# %%
# Get some data from your data folder

data = loadtxt('minimum_salary.dat')

# Never forget to label the axes, if there axes to label, and to give some additional information if you think it is useful
 
plt.xlabel('country')
plt.ylabel('minimum salary in euros')
plt.title('Minimum salary')
plt.legend() 
 
# You can also change the scale (ticks) 
#plt.xticks([], [])
#plt.yticks([], [])

plt.bar(('BEL', 'GRE', 'SPA', 'FRA', 'LUX', 'NET', 'UK'), data)
# Out:
# <Container object of 7 artists>

# %%
# Get some data from your data folder

data = loadtxt('music.dat')

plt.title('Favorite music styles')
plt.legend()

plt.pie(data,labels=('Grunge', 'Hip Hop', 'Metal', 'Schlager', 'Rock'))
# Out:
# ([<matplotlib.patches.Wedge at 0xfeac470>,
#   <matplotlib.patches.Wedge at 0xfeac908>,
#   <matplotlib.patches.Wedge at 0xfeacda0>,
#   <matplotlib.patches.Wedge at 0xff502b0>,
#   <matplotlib.patches.Wedge at 0xff50780>],
#  [Text(1.04069,0.356309,u'Grunge'),
#   Text(0.30689,1.05632,u'Hip Hop'),
#   Text(-1.06544,0.273559,u'Metal'),
#   Text(-0.562917,-0.945052,u'Schlager'),
#   Text(0.685067,-0.86063,u'Rock')])
